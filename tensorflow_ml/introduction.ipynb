# %%
! pip install tensorflow
! pip install tensorflow_hub
! pip install tensorflow_datasets
# Out:
# ...
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ------ --------------------------------- 0.3/1.7 MB ? eta -:--:--
#    ---------------------------------------- 1.7/1.7 MB 5.9 MB/s eta 0:00:00
# ...
# ^C
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#    ---------------------------------------- 0.0/5.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/5.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/5.3 MB ? eta -:--:--
#    --- ------------------------------------ 0.5/5.3 MB 3.4 MB/s eta 0:00:02
#    ----------- ---------------------------- 1.6/5.3 MB 4.7 MB/s eta 0:00:01
#    ------------------------- -------------- 3.4/5.3 MB 6.1 MB/s eta 0:00:01
#    --------------------------------- ------ 4.5/5.3 MB 5.6 MB/s eta 0:00:01
#    ---------------------------------------- 5.3/5.3 MB 5.8 MB/s eta 0:00:00
# ...

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.19.0

# %%
import tensorflow as tf
import numpy as np
import tensorflow.keras as keras
import tensorflow.keras.layers as layers  
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense


linear = Dense(units = 1, input_shape = [1])

#use sequential to create a model and add the linear layer to it
# The Sequential model is a linear stack of layers
model = Sequential([linear])

model.compile(optimizer = 'sgd', loss = 'mean_squared_error')
#optimizer is: random gradient descent
#loss is: mean squared error
#sgd = stochastic gradient descent


#initialize the dataset:
xs = np.array([-1.0, 0.0, 1.0, 2.0, 3.0, 4.0], dtype=float)
ys = np.array([-3.0, -1.0, 1.0, 3.0, 5.0, 7.0], dtype=float)

model.fit(xs, ys, epochs = 500)
# Out:
# Epoch 1/500
# c:\Users\phath\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 265ms/step - loss: 1.1526
# Epoch 2/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 1.0371
# Epoch 3/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.9436
# Epoch 4/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.8673
# Epoch 5/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.8048
# Epoch 6/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.7531
# Epoch 7/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.7099
# Epoch 8/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.6735
# Epoch 9/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.6426
# Epoch 10/500
# ...

# %%
import tensorflow as tf
print(tf.config.list_physical_devices('GPU'))
# Out:
# []

# %%
# Xuất kết quả dự đoán với x = 10
print("Kết quả dự đoán với x = 10 là:" ,model.predict(np.array([10.0])))print("result with value 10.0: ", model.predict(np.array[10.0]))
# Out:
#   Cell In[12], line 2
#     print("Kết quả dự đoán với x = 10 là:" ,model.predict(np.array([10.0])))print("result with value 10.0: ", model.predict(np.array[10.0]))
#                                                                             ^
# SyntaxError: invalid syntax
